# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="./images/btp-banner.gif" alt="BTP A&C">
# </div>

# %% [markdown]
# ## Enhanced Agentic RAG with SAP Generative AI Hub
#
# In this advanced demo, we will explore how to build an **enhanced agentic RAG system** using SAP Generative AI Hub, LangGraph, and SAP HANA Cloud Vector Engine. This implementation builds upon traditional RAG by introducing autonomous agent capabilities that can intelligently select and use multiple tools, manage conversation history, and provide enterprise-grade features like error handling, observability, and result reranking.
#
# The agent architecture enables the system to autonomously decide which data sources to query (supplier contracts, purchase orders, quality incidents, delivery reports) based on user questions, synthesize information from multiple sources, and provide comprehensive, evidence-based answers with proper citations and traceability.

# %% [markdown]
# ## 🎯 Learning Objectives
#
# By the end of this demo, you will be able to:
# - Design and implement an autonomous agent system that intelligently selects and orchestrates multiple retrieval tools based on query analysis
# - Build production-ready RAG systems with enterprise features including memory management, error handling, logging, and performance monitoring
# - Implement result reranking strategies to improve answer quality across multiple data sources
# - Create evaluation frameworks to measure and improve agent performance
# - Configure and optimize agent behavior through centralized configuration management
# - Understand the differences between streaming and non-streaming response modes for real-time user experiences

# %% [markdown]
# ## 🚨 Requirements
#
# Please review the following requirements before starting the demo:
# - Complete the notebook **Retrieval-Augmented Generation with SAP HANA Cloud Vector Engine** (2-rag_with_hana_vectordb.ipynb)
# - Complete the notebook **Agentic RAG with SAP Generative AI Hub** (5-agentic-rag.ipynb)
# - Basic understanding of LangChain and LangGraph concepts
# - Familiarity with agent-based systems and tool use patterns

# %% [markdown]
# ### Step 1: Install Python packages
#
# Run the following package installations. **pip** is the package installer for Python. You can use pip to install packages from the Python Package Index and other indexes.
#
# ⚠️ **Note:** Jupyter Notebook kernel restart required after package installation.

# %%
# %pip install -U langchain_core
# %pip install -U gen-ai-hub-proxy-langchain
# %pip install -U langgraph 
# %pip install -U sap-ai-sdk-gen[all] 
# %pip install -U hdbcli 
# %pip install -U langchain-hana 
# %pip install -U python-dotenv
# %pip install -U sentence-transformers

# kernel restart required!!!
# Out:
# Requirement already satisfied: langchain_core in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (1.4.7)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting langchain_core
#   Downloading langchain_core-1.4.8-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain_core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain_core) (0.0.17)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain_core) (0.8.16)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\I841302\AppData\Roaming\Python\Python314\site-packages (from langchain_core) (26.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain_core) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain_core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain_core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain_core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain_core) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain_core) (3.1.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (2.34.2)
# Requirement already satisfied: websockets>=15.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (0.25.0)
# Requirement already satisfied: anyio in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (4.13.0)
# Requirement already satisfied: certifi in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (1.0.9)
# Requirement already satisfied: idna in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (3.16)
# Requirement already satisfied: h11>=0.16 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core) (2.7.0)
# Downloading langchain_core-1.4.8-py3-none-any.whl (557 kB)
#    ---------------------------------------- 0.0/557.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/557.4 kB ? eta -:--:--
#    ------------------------------------- -- 524.3/557.4 kB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 557.4/557.4 kB 3.4 MB/s  0:00:00
# Installing collected packages: langchain_core
#   Attempting uninstall: langchain_core
#     Found existing installation: langchain-core 1.4.7
#     Uninstalling langchain-core-1.4.7:
#       Successfully uninstalled langchain-core-1.4.7
# Successfully installed langchain_core-1.4.8
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement gen-ai-hub-proxy-langchain (from versions: none)
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for gen-ai-hub-proxy-langchain
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: langgraph in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (1.1.10)
# Collecting langgraph
#   Downloading langgraph-1.2.6-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: langchain-core<2,>=1.4.7 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langgraph) (1.4.8)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langgraph) (4.1.1)
# Collecting langgraph-prebuilt<1.2.0,>=1.1.0 (from langgraph)
#   Using cached langgraph_prebuilt-1.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.5.0,>=0.4.2 (from langgraph)
#   Using cached langgraph_sdk-0.4.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: pydantic>=2.7.4 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langgraph) (2.13.4)
# Requirement already satisfied: xxhash>=3.5.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langgraph) (3.7.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (0.0.17)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (0.8.16)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\I841302\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2,>=1.4.7->langgraph) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2,>=1.4.7->langgraph) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (15.0.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (2.34.2)
# Requirement already satisfied: zstandard>=0.23.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (0.25.0)
# Requirement already satisfied: anyio in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (4.13.0)
# Requirement already satisfied: certifi in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (1.0.9)
# Requirement already satisfied: idna in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.16)
# Requirement already satisfied: h11>=0.16 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic>=2.7.4->langgraph) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (2.7.0)
# Downloading langgraph-1.2.6-py3-none-any.whl (246 kB)
# Using cached langgraph_prebuilt-1.1.0-py3-none-any.whl (41 kB)
# Using cached langgraph_sdk-0.4.2-py3-none-any.whl (160 kB)
# Installing collected packages: langgraph-sdk, langgraph-prebuilt, langgraph
#
#   Attempting uninstall: langgraph-sdk
#
#     Found existing installation: langgraph-sdk 0.3.15
#
#     Uninstalling langgraph-sdk-0.3.15:
#
#       Successfully uninstalled langgraph-sdk-0.3.15
#
#    ---------------------------------------- 0/3 [langgraph-sdk]
#    ---------------------------------------- 0/3 [langgraph-sdk]
#    ---------------------------------------- 0/3 [langgraph-sdk]
#    ---------------------------------------- 0/3 [langgraph-sdk]
#    ---------------------------------------- 0/3 [langgraph-sdk]
#    ---------------------------------------- 0/3 [langgraph-sdk]
#    ---------------------------------------- 0/3 [langgraph-sdk]
#    ---------------------------------------- 0/3 [langgraph-sdk]
#    ---------------------------------------- 0/3 [langgraph-sdk]
#    ---------------------------------------- 0/3 [langgraph-sdk]
#    ---------------------------------------- 0/3 [langgraph-sdk]
#    ---------------------------------------- 0/3 [langgraph-sdk]
#    ---------------------------------------- 0/3 [langgraph-sdk]
#    ---------------------------------------- 0/3 [langgraph-sdk]
#   Attempting uninstall: langgraph-prebuilt
#    ---------------------------------------- 0/3 [langgraph-sdk]
#     Found existing installation: langgraph-prebuilt 1.0.13
#    ---------------------------------------- 0/3 [langgraph-sdk]
#     Uninstalling langgraph-prebuilt-1.0.13:
#    ---------------------------------------- 0/3 [langgraph-sdk]
#       Successfully uninstalled langgraph-prebuilt-1.0.13
#    ---------------------------------------- 0/3 [langgraph-sdk]
#    ------------- -------------------------- 1/3 [langgraph-prebuilt]
#    ------------- -------------------------- 1/3 [langgraph-prebuilt]
#    ------------- -------------------------- 1/3 [langgraph-prebuilt]
#   Attempting uninstall: langgraph
#    ------------- -------------------------- 1/3 [langgraph-prebuilt]
#     Found existing installation: langgraph 1.1.10
#    ------------- -------------------------- 1/3 [langgraph-prebuilt]
#     Uninstalling langgraph-1.1.10:
#    ------------- -------------------------- 1/3 [langgraph-prebuilt]
#       Successfully uninstalled langgraph-1.1.10
#    ------------- -------------------------- 1/3 [langgraph-prebuilt]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    ---------------------------------------- 3/3 [langgraph]
#
# Successfully installed langgraph-1.2.6 langgraph-prebuilt-1.1.0 langgraph-sdk-0.4.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 1.2.18 requires langgraph<1.2.0,>=1.1.10, but you have langgraph 1.2.6 which is incompatible.
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: sap-ai-sdk-gen[all] in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (6.10.0)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: h11>=0.16.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sap-ai-sdk-gen[all]) (0.16.0)
# Requirement already satisfied: httpx>=0.27.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sap-ai-sdk-gen[all]) (0.28.1)
# Requirement already satisfied: pandas>=2.2.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sap-ai-sdk-gen[all]) (3.0.3)
# Requirement already satisfied: langchain-community~=0.4.1 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sap-ai-sdk-gen[all]) (0.4.2)
# Requirement already satisfied: openai>=1.66.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sap-ai-sdk-gen[all]) (2.41.1)
# Requirement already satisfied: sap-ai-sdk-core>=3.3.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sap-ai-sdk-gen[all]) (3.3.0)
# Requirement already satisfied: packaging>=23.2 in C:\Users\I841302\AppData\Roaming\Python\Python314\site-packages (from sap-ai-sdk-gen[all]) (26.2)
# Requirement already satisfied: langcodes~=3.5.1 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sap-ai-sdk-gen[all]) (3.5.1)
# Requirement already satisfied: langchain~=1.2.14 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sap-ai-sdk-gen[all]) (1.2.18)
# Requirement already satisfied: langchain-openai~=1.1.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sap-ai-sdk-gen[all]) (1.1.16)
# Requirement already satisfied: click>=8.1.7 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sap-ai-sdk-gen[all]) (8.4.1)
# Requirement already satisfied: overloading==0.5.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sap-ai-sdk-gen[all]) (0.5.0)
# Requirement already satisfied: pydantic~=2.12 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sap-ai-sdk-gen[all]) (2.13.4)
# Requirement already satisfied: langchain-classic~=1.0.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sap-ai-sdk-gen[all]) (1.0.8)
# Requirement already satisfied: dacite>=1.8.1 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sap-ai-sdk-gen[all]) (1.9.2)
# Requirement already satisfied: langchain-google-genai~=4.2.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sap-ai-sdk-gen[all]) (4.2.5)
# Requirement already satisfied: aiobotocore>=3.2.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sap-ai-sdk-gen[all]) (3.7.0)
# Requirement already satisfied: boto3>=1.40.61 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sap-ai-sdk-gen[all]) (1.43.0)
# Requirement already satisfied: langchain-aws~=1.4.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sap-ai-sdk-gen[all]) (1.4.7)
# Requirement already satisfied: google-genai~=1.73.1 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sap-ai-sdk-gen[all]) (1.73.1)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-genai~=1.73.1->sap-ai-sdk-gen[all]) (4.13.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai~=1.73.1->sap-ai-sdk-gen[all]) (2.54.0)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-genai~=1.73.1->sap-ai-sdk-gen[all]) (2.34.2)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-genai~=1.73.1->sap-ai-sdk-gen[all]) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-genai~=1.73.1->sap-ai-sdk-gen[all]) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-genai~=1.73.1->sap-ai-sdk-gen[all]) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-genai~=1.73.1->sap-ai-sdk-gen[all]) (1.9.0)
# Requirement already satisfied: sniffio in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-genai~=1.73.1->sap-ai-sdk-gen[all]) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai~=1.73.1->sap-ai-sdk-gen[all]) (3.16)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai~=1.73.1->sap-ai-sdk-gen[all]) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai~=1.73.1->sap-ai-sdk-gen[all]) (49.0.0)
# Requirement already satisfied: certifi in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx>=0.27.0->sap-ai-sdk-gen[all]) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx>=0.27.0->sap-ai-sdk-gen[all]) (1.0.9)
# Requirement already satisfied: langchain-core<2.0.0,>=1.3.3 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain~=1.2.14->sap-ai-sdk-gen[all]) (1.4.8)
# Collecting langgraph<1.2.0,>=1.1.10 (from langchain~=1.2.14->sap-ai-sdk-gen[all])
#   Using cached langgraph-1.1.10-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: numpy<3,>=1.0.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-aws~=1.4.0->sap-ai-sdk-gen[all]) (2.4.6)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-classic~=1.0.0->sap-ai-sdk-gen[all]) (1.1.2)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.17 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-classic~=1.0.0->sap-ai-sdk-gen[all]) (0.8.16)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-classic~=1.0.0->sap-ai-sdk-gen[all]) (6.0.3)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-classic~=1.0.0->sap-ai-sdk-gen[all]) (2.0.51)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (3.14.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (0.4.3)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (2.14.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (1.24.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-core<2.0.0,>=1.3.3->langchain~=1.2.14->sap-ai-sdk-gen[all]) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-core<2.0.0,>=1.3.3->langchain~=1.2.14->sap-ai-sdk-gen[all]) (0.0.17)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-core<2.0.0,>=1.3.3->langchain~=1.2.14->sap-ai-sdk-gen[all]) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.3.3->langchain~=1.2.14->sap-ai-sdk-gen[all]) (3.1.1)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-google-genai~=4.2.0->sap-ai-sdk-gen[all]) (1.2.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-openai~=1.1.0->sap-ai-sdk-gen[all]) (0.13.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain~=1.2.14->sap-ai-sdk-gen[all]) (4.1.1)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.12 (from langgraph<1.2.0,>=1.1.10->langchain~=1.2.14->sap-ai-sdk-gen[all])
#   Using cached langgraph_prebuilt-1.0.13-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph<1.2.0,>=1.1.10->langchain~=1.2.14->sap-ai-sdk-gen[all])
#   Using cached langgraph_sdk-0.3.15-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: xxhash>=3.5.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain~=1.2.14->sap-ai-sdk-gen[all]) (3.7.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.10->langchain~=1.2.14->sap-ai-sdk-gen[all]) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain~=1.2.14->sap-ai-sdk-gen[all]) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic~=1.0.0->sap-ai-sdk-gen[all]) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic~=1.0.0->sap-ai-sdk-gen[all]) (0.25.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from openai>=1.66.0->sap-ai-sdk-gen[all]) (0.15.0)
# Requirement already satisfied: tqdm>4 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from openai>=1.66.0->sap-ai-sdk-gen[all]) (4.67.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic~=2.12->sap-ai-sdk-gen[all]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic~=2.12->sap-ai-sdk-gen[all]) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic~=2.12->sap-ai-sdk-gen[all]) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai~=1.73.1->sap-ai-sdk-gen[all]) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai~=1.73.1->sap-ai-sdk-gen[all]) (2.7.0)
# Requirement already satisfied: greenlet>=1 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-classic~=1.0.0->sap-ai-sdk-gen[all]) (3.5.1)
# Requirement already satisfied: regex in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai~=1.1.0->sap-ai-sdk-gen[all]) (2026.5.9)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from aiobotocore>=3.2.0->sap-ai-sdk-gen[all]) (0.13.0)
# Requirement already satisfied: botocore<1.43.1,>=1.42.90 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from aiobotocore>=3.2.0->sap-ai-sdk-gen[all]) (1.43.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in C:\Users\I841302\AppData\Roaming\Python\Python314\site-packages (from aiobotocore>=3.2.0->sap-ai-sdk-gen[all]) (2.9.0.post0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from aiobotocore>=3.2.0->sap-ai-sdk-gen[all]) (1.1.0)
# Requirement already satisfied: wrapt<3.0.0,>=1.10.10 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from aiobotocore>=3.2.0->sap-ai-sdk-gen[all]) (2.2.1)
# Requirement already satisfied: six>=1.5 in C:\Users\I841302\AppData\Roaming\Python\Python314\site-packages (from python-dateutil<3.0.0,>=2.1->aiobotocore>=3.2.0->sap-ai-sdk-gen[all]) (1.17.0)
# Requirement already satisfied: s3transfer<0.18.0,>=0.17.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from boto3>=1.40.61->sap-ai-sdk-gen[all]) (0.17.1)
# Requirement already satisfied: colorama in C:\Users\I841302\AppData\Roaming\Python\Python314\site-packages (from click>=8.1.7->sap-ai-sdk-gen[all]) (0.4.6)
# Requirement already satisfied: cffi>=2.0.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai~=1.73.1->sap-ai-sdk-gen[all]) (2.0.0)
# Requirement already satisfied: pycparser in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai~=1.73.1->sap-ai-sdk-gen[all]) (3.0)
# Requirement already satisfied: tzdata in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas>=2.2.0->sap-ai-sdk-gen[all]) (2026.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai~=1.73.1->sap-ai-sdk-gen[all]) (0.6.3)
# Requirement already satisfied: sap-ai-sdk-base~=3.4 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sap-ai-sdk-core>=3.3.0->sap-ai-sdk-gen[all]) (3.4.0)
# Requirement already satisfied: aenum~=3.1 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sap-ai-sdk-base~=3.4->sap-ai-sdk-core>=3.3.0->sap-ai-sdk-gen[all]) (3.1.17)
# Requirement already satisfied: pyhumps~=3.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sap-ai-sdk-base~=3.4->sap-ai-sdk-core>=3.3.0->sap-ai-sdk-gen[all]) (3.8.0)
# Using cached langgraph-1.1.10-py3-none-any.whl (173 kB)
# Using cached langgraph_prebuilt-1.0.13-py3-none-any.whl (37 kB)
# Using cached langgraph_sdk-0.3.15-py3-none-any.whl (98 kB)
# Installing collected packages: langgraph-sdk, langgraph-prebuilt, langgraph
#
#   Attempting uninstall: langgraph-sdk
#
#     Found existing installation: langgraph-sdk 0.4.2
#
#     Uninstalling langgraph-sdk-0.4.2:
#
#       Successfully uninstalled langgraph-sdk-0.4.2
#
#    ---------------------------------------- 0/3 [langgraph-sdk]
#    ---------------------------------------- 0/3 [langgraph-sdk]
#    ---------------------------------------- 0/3 [langgraph-sdk]
#    ---------------------------------------- 0/3 [langgraph-sdk]
#    ---------------------------------------- 0/3 [langgraph-sdk]
#    ---------------------------------------- 0/3 [langgraph-sdk]
#    ---------------------------------------- 0/3 [langgraph-sdk]
#    ---------------------------------------- 0/3 [langgraph-sdk]
#    ---------------------------------------- 0/3 [langgraph-sdk]
#   Attempting uninstall: langgraph-prebuilt
#    ---------------------------------------- 0/3 [langgraph-sdk]
#     Found existing installation: langgraph-prebuilt 1.1.0
#    ---------------------------------------- 0/3 [langgraph-sdk]
#     Uninstalling langgraph-prebuilt-1.1.0:
#    ---------------------------------------- 0/3 [langgraph-sdk]
#       Successfully uninstalled langgraph-prebuilt-1.1.0
#    ---------------------------------------- 0/3 [langgraph-sdk]
#    ------------- -------------------------- 1/3 [langgraph-prebuilt]
#    ------------- -------------------------- 1/3 [langgraph-prebuilt]
#   Attempting uninstall: langgraph
#    ------------- -------------------------- 1/3 [langgraph-prebuilt]
#     Found existing installation: langgraph 1.2.6
#    ------------- -------------------------- 1/3 [langgraph-prebuilt]
#     Uninstalling langgraph-1.2.6:
#    ------------- -------------------------- 1/3 [langgraph-prebuilt]
#       Successfully uninstalled langgraph-1.2.6
#    ------------- -------------------------- 1/3 [langgraph-prebuilt]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    ---------------------------------------- 3/3 [langgraph]
#
# Successfully installed langgraph-1.1.10 langgraph-prebuilt-1.0.13 langgraph-sdk-0.3.15
# Requirement already satisfied: hdbcli in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (2.29.23)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: langchain-hana in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (1.1.1)
# Requirement already satisfied: hdbcli<3.0.0,>=2.23.24 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-hana) (2.29.23)
# Requirement already satisfied: langchain<2.0.0,>=1.0.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-hana) (1.2.18)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-hana) (1.0.8)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-hana) (1.4.8)
# Requirement already satisfied: numpy>=2.1.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-hana) (2.4.6)
# Requirement already satisfied: rdflib<8.0.0,>=7.0.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-hana) (7.6.0)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.10 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain<2.0.0,>=1.0.0->langchain-hana) (1.1.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain<2.0.0,>=1.0.0->langchain-hana) (2.13.4)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-hana) (1.1.2)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.17 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-hana) (0.8.16)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-hana) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-hana) (2.34.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-hana) (2.0.51)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-hana) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-hana) (0.0.17)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\I841302\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-hana) (26.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-hana) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-hana) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-hana) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-hana) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain<2.0.0,>=1.0.0->langchain-hana) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.12 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain<2.0.0,>=1.0.0->langchain-hana) (1.0.13)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain<2.0.0,>=1.0.0->langchain-hana) (0.3.15)
# Requirement already satisfied: xxhash>=3.5.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain<2.0.0,>=1.0.0->langchain-hana) (3.7.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.10->langchain<2.0.0,>=1.0.0->langchain-hana) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain<2.0.0,>=1.0.0->langchain-hana) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain<2.0.0,>=1.0.0->langchain-hana) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic<2.0.0,>=1.0.0->langchain-hana) (1.0.0)
# Requirement already satisfied: websockets>=15.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic<2.0.0,>=1.0.0->langchain-hana) (15.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic<2.0.0,>=1.0.0->langchain-hana) (0.25.0)
# Requirement already satisfied: anyio in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain<2.0.0,>=1.0.0->langchain-hana) (4.13.0)
# Requirement already satisfied: certifi in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain<2.0.0,>=1.0.0->langchain-hana) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain<2.0.0,>=1.0.0->langchain-hana) (1.0.9)
# Requirement already satisfied: idna in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain<2.0.0,>=1.0.0->langchain-hana) (3.16)
# Requirement already satisfied: h11>=0.16 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain<2.0.0,>=1.0.0->langchain-hana) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=1.0.0->langchain-hana) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=1.0.0->langchain-hana) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=1.0.0->langchain-hana) (0.4.2)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from rdflib<8.0.0,>=7.0.0->langchain-hana) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests<3.0.0,>=2.0.0->langchain-classic<2.0.0,>=1.0.0->langchain-hana) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests<3.0.0,>=2.0.0->langchain-classic<2.0.0,>=1.0.0->langchain-hana) (2.7.0)
# Requirement already satisfied: greenlet>=1 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-classic<2.0.0,>=1.0.0->langchain-hana) (3.5.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: python-dotenv in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (1.2.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: sentence-transformers in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (5.6.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sentence-transformers) (5.12.1)
# Requirement already satisfied: huggingface-hub>=0.23.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sentence-transformers) (1.19.0)
# Requirement already satisfied: torch>=1.11.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sentence-transformers) (2.12.0)
# Requirement already satisfied: numpy>=1.20.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sentence-transformers) (2.4.6)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sentence-transformers) (1.9.0)
# Requirement already satisfied: scipy>=1.0.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sentence-transformers) (1.17.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm>=4.0.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: packaging>=20.0 in C:\Users\I841302\AppData\Roaming\Python\Python314\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: typer in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.8.0)
# Requirement already satisfied: click>=8.4.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (3.29.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (2026.4.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: anyio in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (4.13.0)
# Requirement already satisfied: certifi in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (3.16)
# Requirement already satisfied: h11>=0.16 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: colorama in C:\Users\I841302\AppData\Roaming\Python\Python314\site-packages (from click>=8.4.0->huggingface-hub>=0.23.0->sentence-transformers) (0.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\I841302\AppData\Roaming\Python\Python314\site-packages (from rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.1.2)
# Requirement already satisfied: joblib>=1.4.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (2.21.2)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: setuptools<82 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\I841302\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Step 2: Import required libraries
#
# Import all necessary Python modules for building the enhanced agentic RAG system, including LangChain components for agent orchestration, SAP AI Core SDK for model access, and supporting libraries for logging and data management.

# %%
import os
import json
import logging
from typing import List, Dict, Any, Optional
from datetime import datetime
import urllib3
urllib3.disable_warnings()

# LangChain and LangGraph imports
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage
from langchain.tools import tool
from langgraph.graph import START, StateGraph, MessagesState
from langgraph.prebuilt import tools_condition, ToolNode
from langgraph.checkpoint.memory import MemorySaver

# SAP AI Core imports
from ai_core_sdk.ai_core_v2_client import AICoreV2Client
from gen_ai_hub.proxy.gen_ai_hub_proxy import GenAIHubProxyClient
from gen_ai_hub.proxy.langchain import OpenAIEmbeddings, ChatOpenAI, ChatBedrock
from gen_ai_hub.proxy.langchain.init_models import init_llm

# HANA imports
from hdbcli import dbapi
from langchain_hana import HanaDB

# Environment variables
from dotenv import load_dotenv
load_dotenv()

print("✅ Libraries imported successfully!")
# Out:
# ✅ Libraries imported successfully!

# %% [markdown]
# ### Step 3: Configure centralized system settings
#
# Establish a centralized configuration dictionary that controls all aspects of the agent system. This approach enables easy experimentation with different parameters (model selection, retrieval settings, agent behavior) without modifying the code throughout the notebook. Key configurations include:
# - **Model Configuration**: LLM selection, token limits, and temperature settings
# - **Retrieval Configuration**: Number of results to retrieve and reranking settings
# - **Agent Configuration**: Iteration limits, streaming behavior, and memory management
# - **Logging Configuration**: Verbosity level and token usage tracking

# %%
# Centralized configuration
CONFIG = {
    # Model Configuration
    "llm_model": "gpt-5",
    "embedding_model": "text-embedding-3-large",
    "max_tokens": 4000,
    "temperature": 0.1,
    
    # Retrieval Configuration
    "top_k_results": 5,
    "rerank_top_k": 5,
    "enable_reranking": True,
    
    # Agent Configuration
    "max_iterations": 15,
    "enable_streaming": True,
    "enable_memory": True,
    
    # Logging Configuration
    "log_level": "INFO",
    "log_token_usage": True,
    
    # Table Names
    "tables": {
        "contracts": "SUPPLIER_CONTRACTS",
        "purchase_orders": "PURCHASE_ORDERS",
        "quality_incidents": "QUALITY_INCIDENTS",
        "delivery_reports": "DELIVERY_REPORT"
    },
}

# Setup logging
logging.basicConfig(
    level=getattr(logging, CONFIG["log_level"]),
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s'
)
logger = logging.getLogger(__name__)

print("✅ Configuration loaded successfully!")
print(json.dumps(CONFIG, indent=2))
# Out:
# ✅ Configuration loaded successfully!
# {
#   "llm_model": "gpt-5",
#   "embedding_model": "text-embedding-3-large",
#   "max_tokens": 4000,
#   "temperature": 0.1,
#   "top_k_results": 5,
#   "rerank_top_k": 5,
#   "enable_reranking": true,
#   "max_iterations": 15,
#   "enable_streaming": true,
#   "enable_memory": true,
#   "log_level": "INFO",
#   "log_token_usage": true,
#   "tables": {
#     "contracts": "SUPPLIER_CONTRACTS",
#     "purchase_orders": "PURCHASE_ORDERS",
#     "quality_incidents": "QUALITY_INCIDENTS",
#     "delivery_reports": "DELIVERY_REPORT"
#   },
#   "schema": "SPURCHASE"
# }

# %% [markdown]
# ### Step 4: Configure AI Core Client
#
# Execute the configuration module below to enable access to SAP's Generative AI foundation models. Running this code block will automatically handle the necessary setup, including authentication and environment configuration, to ensure seamless connectivity to the Generative AI services.

# %%
try:
    # Get the AI Core credentials from environment variables
    URL = os.getenv('AICORE_AUTH_URL')
    CLIENT_ID = os.getenv('AICORE_CLIENT_ID')
    CLIENT_SECRET = os.getenv('AICORE_CLIENT_SECRET')
    RESOURCE_GROUP = os.getenv('AICORE_RESOURCE_GROUP')
    API_URL = os.getenv('AICORE_BASE_URL')

    if not all([URL, CLIENT_ID, CLIENT_SECRET, RESOURCE_GROUP, API_URL]):
        raise ValueError("Missing required AI Core environment variables")

    # Set up the AICoreV2Client
    ai_core_client = AICoreV2Client(
        base_url=API_URL,
        auth_url=URL,
        client_id=CLIENT_ID,
        client_secret=CLIENT_SECRET,
        resource_group=RESOURCE_GROUP
    )

    # Initialize GenAIHub proxy client
    proxy_client = GenAIHubProxyClient(ai_core_client=ai_core_client)
    logger.info("AI Core client initialized successfully")
    print("✅ AI Core Client connection is established successfully!")
    
except Exception as e:
    logger.error(f"Failed to initialize AI Core client: {str(e)}")
    raise
# Out:
# 2026-06-23 09:18:03,319 - __main__ - INFO - AI Core client initialized successfully
# ✅ AI Core Client connection is established successfully!

# %% [markdown]
# Initialize the embedding and LLM models

# %%
try:
    # Initialize embedding and LLM models
    embedding_model = OpenAIEmbeddings(
        proxy_model_name=CONFIG["embedding_model"],
        proxy_client=proxy_client
    )
    
    llm = init_llm(
        CONFIG["llm_model"],
        max_tokens=CONFIG["max_tokens"],
        temperature=CONFIG["temperature"]
    )
    
    logger.info(f"Models initialized: {CONFIG['llm_model']}, {CONFIG['embedding_model']}")
    print("✅ AI models are initialized successfully!")
    
except Exception as e:
    logger.error(f"Failed to initialize models: {str(e)}")
    raise
# Out:
# 2026-06-23 09:18:12,385 - __main__ - INFO - Models initialized: gpt-5, text-embedding-3-large
# ✅ AI models are initialized successfully!

# %% [markdown]
# ### Step 5: Connect to SAP HANA Cloud database
#
# The provided Python script imports database connection modules and initiates a connection to a SAP HANA Cloud instance using the **dbapi** module. The connection credentials are retrieved from environment variables to ensure secure access to the SAP HANA Cloud database.

# %%
try:
    # Get the HANA Cloud credentials from environment variables
    HANA_USER = os.getenv('HANA_VECTOR_USER')
    HANA_PASS = os.getenv('HANA_VECTOR_PASS')
    HANA_HOST = os.getenv('HANA_VECTOR_HOST')

    if not all([HANA_USER, HANA_PASS, HANA_HOST]):
        raise ValueError("Missing required HANA Cloud environment variables")

    # Establish connection to SAP HANA Cloud database
    conn = dbapi.connect(
        user=HANA_USER,
        password=HANA_PASS,
        address=HANA_HOST,
        port=443,
    )
    cursor = conn.cursor()
    cursor.execute("SET SCHEMA SPURCHASE")
    logger.info("HANA Cloud connection established")
    print("✅ HANA Cloud connection is established successfully!")
    
except Exception as e:
    logger.error(f"Failed to connect to HANA Cloud: {str(e)}")
    raise
# Out:
# 2026-06-23 09:18:14,777 - __main__ - INFO - HANA Cloud connection established
# ✅ HANA Cloud connection is established successfully!

# %% [markdown]
# ### Step 6: Implement result reranking
#
# Result reranking is a crucial technique to improve answer quality when retrieving information from multiple sources. After initial vector similarity search retrieves candidate documents, a cross-encoder model re-scores these results based on their actual relevance to the query. This two-stage approach (fast retrieval + accurate reranking) significantly improves the precision of information provided to the LLM, leading to better final answers.

# %%
from sentence_transformers import CrossEncoder

# Initialize reranker model (lightweight cross-encoder)
reranker_model = None

def initialize_reranker():
    """Initialize the reranker model lazily."""
    global reranker_model
    if reranker_model is None and CONFIG["enable_reranking"]:
        try:
            reranker_model = CrossEncoder('cross-encoder/ms-marco-MiniLM-L-6-v2')
            logger.info("Reranker model initialized")
        except Exception as e:
            logger.warning(f"Failed to initialize reranker: {str(e)}")
            reranker_model = None
    return reranker_model

def rerank_documents(query: str, documents: List[Any], top_k: int = None) -> List[Any]:
    """
    Rerank documents using a cross-encoder model.
    
    Args:
        query: The user query
        documents: List of document objects with page_content attribute
        top_k: Number of top documents to return (default from config)
    
    Returns:
        Reranked and filtered list of documents
    """
    if not documents:
        return documents
    
    if top_k is None:
        top_k = CONFIG["rerank_top_k"]
    
    if not CONFIG["enable_reranking"]:
        return documents[:top_k]
    
    try:
        reranker = initialize_reranker()
        if reranker is None:
            return documents[:top_k]
        
        # Prepare query-document pairs
        pairs = [[query, doc.page_content] for doc in documents]
        
        # Get scores
        scores = reranker.predict(pairs)
        
        # Sort documents by score
        scored_docs = list(zip(documents, scores))
        scored_docs.sort(key=lambda x: x[1], reverse=True)
        
        # Return top-k documents
        reranked_docs = [doc for doc, score in scored_docs[:top_k]]
        
        logger.info(f"Reranked {len(documents)} documents to top {top_k}")
        return reranked_docs
        
    except Exception as e:
        logger.warning(f"Reranking failed: {str(e)}. Returning original top-k.")
        return documents[:top_k]

print("✅ Reranker initialized!")
# Out:
# ✅ Reranker initialized!

# %% [markdown]
# ### Step 7: Define agent tools with enhanced capabilities
#
# Define the specialized tools that the agent can autonomously select and use to retrieve information. Each tool is designed as an independent function with:
# - **Clear documentation**: Describes when and how to use the tool
# - **Error handling**: Graceful failure with informative error messages
# - **Structured outputs**: JSON-formatted results with metadata for traceability
# - **Logging**: Tracks tool usage for debugging and monitoring
#
# The agent will intelligently choose which tools to invoke based on the user's question and the tool descriptions.

# %%
def format_tool_results(documents: List[Any], tool_name: str) -> Dict[str, Any]:
    """
    Format tool results with metadata and citations.
    
    Args:
        documents: List of retrieved documents
        tool_name: Name of the tool that retrieved the documents
    
    Returns:
        Structured result dictionary
    """
    results = []
    for idx, doc in enumerate(documents):
        results.append({
            "rank": idx + 1,
            "content": doc.page_content,
            "metadata": doc.metadata,
            "source": tool_name
        })
    
    return {
        "tool": tool_name,
        "count": len(results),
        "results": results,
        "timestamp": datetime.now().isoformat()
    }

@tool(response_format="content_and_artifact")
def get_supplier_contract(name: str):
    """Returns the most relevant supplier contract data based on the supplier name.
    
    Use this tool when you need information about:
    - Contract terms and conditions
    - Late delivery penalties
    - Contract validity and end dates
    - Pricing agreements
    
    Args:
        name: The name of the supplier (e.g., 'Acme Corp', 'Sigma Electronics')
        
    Returns:
        Structured contract information with metadata
    """
    try:
        logger.info(f"Retrieving supplier contracts for: {name}")
        
        # Initialize HanaDB with existing table
        db = HanaDB(
            embedding=embedding_model,
            connection=conn,
            table_name=CONFIG["tables"]["contracts"]
        )

        # Perform similarity search
        contracts = db.similarity_search(name, k=CONFIG["top_k_results"])
        
        if not contracts:
            logger.warning(f"No contracts found for supplier: {name}")
            return "No supplier contract data found for the given name.", []
        
        # Format results
        formatted = format_tool_results(contracts, "get_supplier_contract")
        serialized = json.dumps(formatted, indent=2)
        
        logger.info(f"Retrieved {len(contracts)} contract documents")
        return serialized, contracts
        
    except Exception as e:
        logger.error(f"Error in get_supplier_contract: {str(e)}")
        return f"Error retrieving supplier contracts: {str(e)}", []

# %%
@tool(response_format="content_and_artifact")
def get_purchase_order(name: str):
    """Returns the most relevant purchase order data based on the supplier name.
    
    Use this tool when you need information about:
    - Order status and fulfillment
    - Order quantities and dates
    - Payment terms
    
    Args:
        name: The name of the supplier
        
    Returns:
        Structured purchase order information
    """
    try:
        logger.info(f"Retrieving purchase orders for: {name}")
        
        db = HanaDB(
            embedding=embedding_model,
            connection=conn,
            table_name=CONFIG["tables"]["purchase_orders"]
        )

        purchase_orders = db.similarity_search(name, k=CONFIG["top_k_results"])
        
        if not purchase_orders:
            logger.warning(f"No purchase orders found for supplier: {name}")
            return "No purchase order data found for the given name.", []
        
        formatted = format_tool_results(purchase_orders, "get_purchase_order")
        serialized = json.dumps(formatted, indent=2)
        
        logger.info(f"Retrieved {len(purchase_orders)} purchase order documents")
        return serialized, purchase_orders
        
    except Exception as e:
        logger.error(f"Error in get_purchase_order: {str(e)}")
        return f"Error retrieving purchase orders: {str(e)}", []

# %%
@tool(response_format="content_and_artifact")
def get_quality_incident(name: str):
    """Returns the most relevant quality incident data based on the supplier name.
    
    Use this tool when you need information about:
    - Product quality issues
    - Incident severity levels
    - Resolution status
    - Quality metrics and trends
    
    Args:
        name: The name of the supplier
        
    Returns:
        Structured quality incident information
    """
    try:
        logger.info(f"Retrieving quality incidents for: {name}")
        
        db = HanaDB(
            embedding=embedding_model,
            connection=conn,
            table_name=CONFIG["tables"]["quality_incidents"]
        )

        incidents = db.similarity_search(name, k=CONFIG["top_k_results"])
        
        if not incidents:
            logger.warning(f"No quality incidents found for supplier: {name}")
            return "No quality incident data found for the given name.", []
        
        formatted = format_tool_results(incidents, "get_quality_incident")
        serialized = json.dumps(formatted, indent=2)
        
        logger.info(f"Retrieved {len(incidents)} quality incident documents")
        return serialized, incidents
        
    except Exception as e:
        logger.error(f"Error in get_quality_incident: {str(e)}")
        return f"Error retrieving quality incidents: {str(e)}", []

# %%
@tool(response_format="content_and_artifact")
def get_delivery_report(name: str):
    """Returns the most relevant delivery report data based on the supplier name.
    
    Use this tool when you need information about:
    - Delivery timeliness (delays, on-time, early)
    - Delivery performance
    - Shipment details
    
    Args:
        name: The name of the supplier
        
    Returns:
        Structured delivery report information
    """
    try:
        logger.info(f"Retrieving delivery reports for: {name}")
        
        db = HanaDB(
            embedding=embedding_model,
            connection=conn,
            table_name=CONFIG["tables"]["delivery_reports"]
        )

        reports = db.similarity_search(name, k=CONFIG["top_k_results"])
        
        if not reports:
            logger.warning(f"No delivery reports found for supplier: {name}")
            return "No delivery report data found for the given name.", []
        
        formatted = format_tool_results(reports, "get_delivery_report")
        serialized = json.dumps(formatted, indent=2)
        
        logger.info(f"Retrieved {len(reports)} delivery report documents")
        return serialized, reports
        
    except Exception as e:
        logger.error(f"Error in get_delivery_report: {str(e)}")
        return f"Error retrieving delivery reports: {str(e)}", []

# %%
# Collect all tools
tools = [
    get_supplier_contract,
    get_purchase_order,
    get_quality_incident,
    get_delivery_report
]

print(f"✅ {len(tools)} tools defined successfully!")
# Out:
# ✅ 4 tools defined successfully!

# %% [markdown]
# ### Step 8: Implement query analysis for intelligent tool routing
#
# The query analyzer examines the user's question to determine which tools are most relevant before the agent begins execution. This optimization:
# - Reduces unnecessary tool calls by identifying intent upfront
# - Provides insights into the query type for better handling
# - Helps the agent make more informed decisions about tool selection
#
# For example, a query about "delivery performance" will suggest the delivery_report tool, while a question about "contract penalties" will route to the contract tool.

# %%
def analyze_query(query: str) -> Dict[str, Any]:
    """
    Analyze the user query to extract key information and suggest relevant tools.
    
    Args:
        query: The user's question
    
    Returns:
        Dictionary with analysis results
    """
    query_lower = query.lower()
    
    analysis = {
        "query": query,
        "suggested_tools": [],
        "keywords": [],
        "query_type": "general"
    }
    
    # Detect query intent - check for "overall performance" first
    if 'performance' in query_lower and 'overall' in query_lower:
        analysis["suggested_tools"] = [tool.name for tool in tools]
        analysis["query_type"] = "comprehensive"
        return analysis
    
    if any(word in query_lower for word in ['contract', 'penalty', 'agreement', 'term']):
        analysis["suggested_tools"].append("get_supplier_contract")
        analysis["query_type"] = "contract"
    
    if any(word in query_lower for word in ['order', 'purchase', 'po']):
        analysis["suggested_tools"].append("get_purchase_order")
        analysis["query_type"] = "purchase_order"
    
    if any(word in query_lower for word in ['quality', 'defect', 'incident', 'issue']):
        analysis["suggested_tools"].append("get_quality_incident")
        analysis["query_type"] = "quality"
    
    if any(word in query_lower for word in ['delivery', 'delay', 'late', 'on-time', 'early']):
        analysis["suggested_tools"].append("get_delivery_report")
        analysis["query_type"] = "delivery"
    
    # If no specific tool identified, suggest all for comprehensive search
    if not analysis["suggested_tools"]:
        analysis["suggested_tools"] = [tool.name for tool in tools]
        analysis["query_type"] = "comprehensive"
    
    logger.info(f"Query analysis: type={analysis['query_type']}, tools={analysis['suggested_tools']}")
    return analysis

print("✅ Query analyzer ready!")
# Out:
# ✅ Query analyzer ready!

# %% [markdown]
# ### Step 9: Configure system prompt for the agent
#
# The system message provides crucial instructions to the LLM about how to behave as an analyst. A well-crafted system prompt ensures the agent:
# - Understands its role and responsibilities
# - Follows consistent response formatting
# - Properly cites sources and shows calculations
# - Handles missing data appropriately
# - Synthesizes information from tool results correctly

# %%
sys_msg = SystemMessage(content="""
You are an AI analyst for Supplier Performance Management.

TOOL USAGE INSTRUCTIONS:
1. First, call the necessary tools to gather data
2. After receiving tool results, ANALYZE the JSON data returned
3. Extract relevant information from the tool results
4. Formulate a comprehensive answer based on the data

RESPONSE REQUIREMENTS (AFTER TOOLS):
- Start with a direct answer to the user's question
- Include specific numbers, dates, and metrics from the retrieved data
- Cite sources: (Source: [Tool Name] | Supplier: [Name])
- Show calculations if computing metrics
- Never fabricate information not in the tool results

IMPORTANT: After calling all necessary tools, you MUST provide a final answer. Do not leave the response empty.

Example Response Format:
"Based on the retrieved data, Supplier X shows the following:

Delivery Performance:
- 15 deliveries tracked
- On-time rate: 80% (12 out of 15 deliveries)
(Source: get_delivery_report | Supplier: X)

Overall Assessment: [Your assessment here]"

Domain Rules:
- Delay values: negative=early, 0=on-time, positive=late
- Always extract and use specific data points from tool results
""")

print("✅ System message configured!")
# Out:
# ✅ System message configured!

# %% [markdown]
# ### Step 10: Build the agent graph with memory
#
# Create the agent's computational graph using LangGraph, which defines how the agent processes user inputs and decides when to use tools. The graph includes:
# - **Assistant Node**: Makes decisions about which tools to call and generates final responses
# - **Tools Node**: Executes the selected tools and returns results
# - **Memory/Checkpointing**: Enables conversation history tracking across multiple turns
# - **Conditional Edges**: Routes between assistant and tools based on whether tool calls are needed

# %%
# Bind tools to LLM
llm_with_tools = llm.bind_tools(tools)

print("✅ LLM with tools bound successfully!")
# Out:
# ✅ LLM with tools bound successfully!

# %%
def assistant(state: MessagesState):
    """Assistant node with enhanced logging."""
    try:
        response = llm_with_tools.invoke([sys_msg] + state["messages"])
        
        # Log token usage if available
        if CONFIG["log_token_usage"] and hasattr(response, 'response_metadata'):
            usage = response.response_metadata.get('token_usage', {})
            logger.info(f"Token usage: {usage}")
        
        return {"messages": [response]}
        
    except Exception as e:
        logger.error(f"Error in assistant node: {str(e)}")
        error_msg = AIMessage(content=f"I encountered an error: {str(e)}")
        return {"messages": [error_msg]}

# %%
# Build the graph
builder = StateGraph(MessagesState)

# Add nodes
builder.add_node("assistant", assistant)
builder.add_node("tools", ToolNode(tools))

# Add edges
builder.add_edge(START, "assistant")
builder.add_conditional_edges(
    "assistant",
    tools_condition,
)
builder.add_edge("tools", "assistant")

# Add memory/checkpointing
if CONFIG["enable_memory"]:
    memory = MemorySaver()
    graph = builder.compile(checkpointer=memory)
    logger.info("Graph compiled with memory checkpointing")
else:
    graph = builder.compile(recursion_limit=20)
    logger.info("Graph compiled without memory")

print("✅ Agent graph built successfully!")
# Out:
# 2026-06-23 09:19:29,629 - __main__ - INFO - Graph compiled with memory checkpointing
# ✅ Agent graph built successfully!

# %% [markdown]
# Visualize the agent graph structure

# %%
# Visualize the graph
try:
    from IPython.display import Image, display
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception as e:
    print(f"Could not visualize graph: {str(e)}")

# %% [markdown]
# ### Step 11: Execute queries with the agent
#
# The execute_query function provides a unified interface for interacting with the agent. It supports two modes:
# - **Streaming Mode** (default): Displays responses progressively as they're generated, similar to ChatGPT's typing effect
# - **Non-Streaming Mode**: Waits for the complete response before displaying, useful for debugging
#
# The function also performs query analysis before execution and manages conversation threading for multi-turn interactions.

# %%
def execute_query(user_input: str, thread_id: str = "default", stream: bool = None):
    """
    Execute a query with the agent.
    
    Args:
        user_input: The user's question
        thread_id: Conversation thread ID for memory
        stream: Whether to stream the response (default from config)
    
    Returns:
        Final response message
    """
    if stream is None:
        stream = CONFIG["enable_streaming"]
    
    # Analyze query
    analysis = analyze_query(user_input)
    print(f"\n📊 Query Analysis: {analysis['query_type'].upper()}")
    print(f"🔧 Suggested tools: {', '.join(analysis['suggested_tools'])}\n")
    
    # Prepare config for conversation threading
    config = {"configurable": {"thread_id": thread_id}}
    
    if stream:
        print("💬 Streaming response...\n")
        print("="*80)
        
        # Stream the response
        for event in graph.stream(
            {"messages": [("user", user_input)]},
            config=config,
            stream_mode="values"
        ):
            message = event["messages"][-1]
            if hasattr(message, 'content') and message.content:
                message.pretty_print()
        
        print("="*80)
        return event["messages"][-1]
    else:
        # Non-streaming execution
        result = graph.invoke(
            {"messages": [("user", user_input)]},
            config=config
        )
        
        print("\n💬 Response:\n")
        print("="*80)
        for message in result["messages"]:
            message.pretty_print()
        print("="*80)
        
        return result["messages"][-1]

print("✅ Query execution helper ready!")
# Out:
# ✅ Query execution helper ready!

# %% [markdown]
# ### Step 12: Test the enhanced agent
#
# Run example queries to test the agent's capabilities. Each query demonstrates different aspects:
# - Single-tool queries (e.g., contract information)
# - Multi-tool queries (e.g., overall performance requiring multiple data sources)
# - Conversation memory (follow-up questions in the same thread)

# %%
# Test Query 1: Delivery Performance
response = execute_query(
    "Tell me about PulseWave Materials delivery performance",
    thread_id="test_session_1",
    stream=False  # Use False to see all messages for debugging
)
# Out:
# 2026-06-23 09:19:39,818 - __main__ - INFO - Query analysis: type=delivery, tools=['get_delivery_report']
# 📊 Query Analysis: DELIVERY
# 🔧 Suggested tools: get_delivery_report
# 2026-06-23 09:19:42,415 - httpx - INFO - HTTP Request: POST https://api.ai.prod.eu-central-1.aws.ml.hana.ondemand.com/v2/inference/deployments/d03d288591de6d5d/chat/completions?api-version=2025-03-01-preview "HTTP/1.1 200 OK"
# 2026-06-23 09:19:42,426 - __main__ - INFO - Token usage: {'completion_tokens': 155, 'prompt_tokens': 692, 'total_tokens': 847, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 8, 'engine_ttft_ms': 50, 'engine_ttlt_ms': 1536, 'pre_inference_ms': 120, 'service_tbt_ms': 8, 'service_ttft_ms': 257, 'service_ttlt_ms': 1739, 'total_duration_ms': 1625, 'user_visible_ttft_ms': 137}}
# 2026-06-23 09:19:42,433 - __main__ - INFO - Retrieving delivery reports for: PulseWave Materials
# 2026-06-23 09:19:42,437 - __main__ - ERROR - Error in get_delivery_report: HanaDB.__init__() got an unexpected keyword argument 'schema'
# 2026-06-23 09:19:46,242 - httpx - INFO - HTTP Request: POST https://api.ai.prod.eu-central-1.aws.ml.hana.ondemand.com/v2/inference/deployments/d03d288591de6d5d/chat/completions?api-version=2025-03-01-preview "HTTP/1.1 200 OK"
# 2026-06-23 09:19:46,250 - __main__ - INFO - Token usage: {'completion_tokens': 351, 'prompt_tokens': 743, 'total_tokens': 1094, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 256, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 8, 'engine_ttft_ms': 37, 'engine_ttlt_ms': 3139, 'pre_inference_ms': 124, 'service_tbt_ms': 8, 'service_ttft_ms': 256, 'service_ttlt_ms': 3354, 'total_duration_ms': 3236, 'user_visible_ttft_ms': 132}}
# 2026-06-23 09:19:46,260 - __main__ - INFO - Retrieving delivery reports for: PulseWave Materials
# 2026-06-23 09:19:46,281 - __main__ - INFO - Retrieving purchase orders for: PulseWave Materials
# 2026-06-23 09:19:46,285 - __main__ - INFO - Retrieving supplier contracts for: PulseWave Materials
# 2026-06-23 09:19:46,286 - __main__ - ERROR - Error in get_delivery_report: HanaDB.__init__() got an unexpected keyword argument 'schema'
# 2026-06-23 09:19:46,289 - __main__ - INFO - Retrieving quality incidents for: PulseWave Materials
# 2026-06-23 09:19:46,297 - __main__ - ERROR - Error in get_purchase_order: HanaDB.__init__() got an unexpected keyword argument 'schema'
# 2026-06-23 09:19:46,309 - __main__ - ERROR - Error in get_supplier_contract: HanaDB.__init__() got an unexpected keyword argument 'schema'
# 2026-06-23 09:19:46,318 - __main__ - ERROR - Error in get_quality_incident: HanaDB.__init__() got an unexpected keyword argument 'schema'
# 2026-06-23 09:19:59,190 - httpx - INFO - HTTP Request: POST https://api.ai.prod.eu-central-1.aws.ml.hana.ondemand.com/v2/inference/deployments/d03d288591de6d5d/chat/completions?api-version=2025-03-01-preview "HTTP/1.1 200 OK"
# 2026-06-23 09:19:59,198 - __main__ - INFO - Token usage: {'completion_tokens': 1381, 'prompt_tokens': 925, 'total_tokens': 2306, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1024, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 8, 'engine_ttft_ms': 60, 'engine_ttlt_ms': 12163, 'pre_inference_ms': 108, 'service_tbt_ms': 8, 'service_ttft_ms': 255, 'service_ttlt_ms': 12355, 'total_duration_ms': 12254, 'user_visible_ttft_ms': 147}}
# 💬 Response:
#
# ================================================================================
# ================================ Human Message =================================
#
# Tell me about PulseWave Materials delivery performance
# ================================== Ai Message ==================================
# Tool Calls:
#   get_delivery_report (call_UgVo6Pka7j0p7mh9dRElA2hS)
#  Call ID: call_UgVo6Pka7j0p7mh9dRElA2hS
#   Args:
#     name: PulseWave Materials
# ================================= Tool Message =================================
# Name: get_delivery_report
#
# Error retrieving delivery reports: HanaDB.__init__() got an unexpected keyword argument 'schema'
# ================================== Ai Message ==================================
# Tool Calls:
#   get_delivery_report (call_4LVFsZS1owgflwGASeEfun1Z)
#  Call ID: call_4LVFsZS1owgflwGASeEfun1Z
#   Args:
#     name: PulseWave Materials
#   get_purchase_order (call_vulTpeXh1MKlx8V0tUcfI9xI)
#  Call ID: call_vulTpeXh1MKlx8V0tUcfI9xI
#   Args:
#     name: PulseWave Materials
#   get_supplier_contract (call_JjX1L3ipt0L36FDvebQcfHnm)
#  Call ID: call_JjX1L3ipt0L36FDvebQcfHnm
#   Args:
#     name: PulseWave Materials
#   get_quality_incident (call_unYJJvCbR4wqcgG8OR4SP3Md)
#  Call ID: call_unYJJvCbR4wqcgG8OR4SP3Md
#   Args:
#     name: PulseWave Materials
# ================================= Tool Message =================================
# Name: get_delivery_report
#
# Error retrieving delivery reports: HanaDB.__init__() got an unexpected keyword argument 'schema'
# ================================= Tool Message =================================
# Name: get_purchase_order
#
# Error retrieving purchase orders: HanaDB.__init__() got an unexpected keyword argument 'schema'
# ================================= Tool Message =================================
# Name: get_supplier_contract
#
# Error retrieving supplier contracts: HanaDB.__init__() got an unexpected keyword argument 'schema'
# ================================= Tool Message =================================
# Name: get_quality_incident
#
# Error retrieving quality incidents: HanaDB.__init__() got an unexpected keyword argument 'schema'
# ================================== Ai Message ==================================
#
# I’m currently unable to report PulseWave Materials’ delivery performance because the data retrieval tools returned a backend error, so no shipment metrics could be loaded at this time.
#
# What happened:
# - Delivery report retrieval failed with: "HanaDB.__init__() got an unexpected keyword argument 'schema'"
#   (Source: get_delivery_report | Supplier: PulseWave Materials)
# - Related data sources (purchase orders, contracts, and quality incidents) also returned the same error, preventing cross-checks or SLA comparisons:
#   - (Source: get_purchase_order | Supplier: PulseWave Materials)
#   - (Source: get_supplier_contract | Supplier: PulseWave Materials)
#   - (Source: get_quality_incident | Supplier: PulseWave Materials)
#
# Because no data was retrieved, I cannot provide counts, dates, on-time rates, or delay metrics without risking fabrication.
#
# Next steps I can take:
# - Retry once the HanaDB connector issue is resolved.
# - If you have a CSV/export of recent deliveries (fields: delivery date, promised date, delay days, quantity, shipment ID), I can compute:
#   - On-time rate = on-time deliveries / total deliveries
#   - Average delay (days) = mean of delay values (note: negative=early, 0=on-time, positive=late)
#   - Early/on-time/late distribution
#   - Quantity-weighted on-time rate and average delay
#   - Trend by week/month vs. contract SLA (once contract terms are accessible)
#
# Please let me know if you’d like me to:
# - Attempt another retrieval now,
# - Use a specific date range (e.g., last 90 days) once the data source is back,
# - Or process a file you can share.
# ================================================================================

# %%
# Test Query 2: Contract Information
response = execute_query(
    "What is the late delivery penalty for Sigma Electronics Co.?",
    thread_id="test_session_2"
)

# %%
# Test Query 3: Quality Issues
response = execute_query(
    "Show me quality incidents with high severity from PulseWave Materials Inc.",
    thread_id="test_session_3"
)

# %% [markdown]
# ### Cleanup
#
# Close database connections when done to free up resources.

# %%
# Close HANA connection
try:
    if 'conn' in globals():
        conn.close()
        print("✅ HANA connection closed")
except Exception as e:
    print(f"Error closing connection: {str(e)}")
